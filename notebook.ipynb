# %%
#!/usr/bin/env python3
import os
import sys

import music21
import numpy as np
from keras.layers import LSTM, Dense, Input, concatenate
from keras.models import Model
from keras.utils import to_categorical
from loguru import logger
from midi2audio import FluidSynth
from tqdm import tqdm

SEQUENCE_LENGTH = 32
BATCH_SIZE = 8
EPOCHS = 100
QL_TO_ORDINAL = {}
ORDINAL_TO_QL = {}
# Out:
# 2023-03-14 23:29:12.605008: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-14 23:29:12.680628: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-14 23:29:12.680649: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-14 23:29:13.134826: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-14 23:29:13.134875: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-14 23:29:13.134881: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
def setup_logging(level="DEBUG", show_module=False):
    """
    Setups better log format for loguru
    """
    logger.remove(0)    # Remove the default logger
    log_level = level
    log_fmt = u"<green>["
    log_fmt += u"{file:10.10}…:{line:<3} | " if show_module else ""
    log_fmt += u"{time:HH:mm:ss.SSS}]</green> <level>{level: <8}</level> | <level>{message}</level>"
    logger.add(sys.stderr, level=log_level, format=log_fmt, colorize=True, backtrace=True, diagnose=True)


def get_chord(note):
    duration = music21.duration.Duration(ORDINAL_TO_QL[note[1]])
    pitch_octave_pairs = [(note[i], note[i + 1]) for i in range(2, len(note), 2) if note[i] != 0 and note[i + 1] != 0]
    pitches = [music21.pitch.Pitch(pitch, octave=octave) for pitch, octave in pitch_octave_pairs]

    return music21.chord.Chord(pitches, duration=duration)


def get_note(note):
    duration = music21.duration.Duration(ORDINAL_TO_QL[note[1]])
    pitch, octave = note[2] - 1, note[3]
    pitch = music21.pitch.Pitch(pitch, octave=octave)

    return music21.note.Note(pitch=pitch, duration=duration)


def get_rest(note):
    duration = music21.duration.Duration(ORDINAL_TO_QL[note[1]])

    return music21.note.Rest(duration=duration)


def play_song(song):
    stream = music21.stream.Stream()
    for note in song:
        if note[0] == 1:   # Rest
            stream.append(get_rest(note))
        elif note[0] == 2: # Note
            stream.append(get_note(note))
        elif note[0] == 3: # Chord
            stream.append(get_chord(note))

    stream.write('midi', fp='generated_music.mid')
    sf2_path = '/usr/share/soundfonts/freepats-general-midi.sf2' # path to sound font file
    FluidSynth(sound_font=sf2_path).play_midi("generated_music.mid")

# %%
def parse_corpus(corpi):
    notes = []
    for corpus in corpi:
        logger.info(f'Parsing {corpus}')
        parsed = music21.converter.parse(corpus)
        elements = parsed.elements[1].flat.notesAndRests
        for element in elements:
            # duration = element.duration.fullName # too many different values
            duration = element.duration.quarterLengthNoTuplets # less precise
            if duration not in QL_TO_ORDINAL:
                ordinal = len(QL_TO_ORDINAL) + 1
                QL_TO_ORDINAL[duration] = ordinal
                ORDINAL_TO_QL[ordinal] = duration
            else:
                ordinal = QL_TO_ORDINAL[duration]

            if isinstance(element, music21.note.Rest):
                feat = [1, ordinal]

            if isinstance(element, music21.note.Note):
                feat = [2, ordinal, element.pitch.pitchClass + 1, element.pitch.octave]

            if isinstance(element, music21.chord.Chord):
                chord_notes = []
                for pitch in element.pitches:
                    chord_notes = chord_notes + [pitch.pitchClass + 1, pitch.octave]
                feat = [3, ordinal, *chord_notes]

            notes.append(feat)

    # ensures all notes are the same length by padding with zeros
    max_len = max(len(note) for note in notes)
    notes = [note + [0] * (max_len - len(note)) for note in notes]
    return notes

# %%
## Load the midi files
# corpi = [c for c in music21.corpus.getComposer("mozart")[2:5]]
# corpi = [os.path.join('./midi', f) for f in os.listdir('./midi') if f.endswith('.mid')]
# corpi = [os.path.join('./midi', f) for f in os.listdir('./midi') if f.endswith('.mid') and f.startswith("mid")][5:10]
# corpi = [os.path.join('./midi/pokemon', f) for f in os.listdir('./midi/pokemon')]
corpi = ["./midi/pokemon/Pokemon_game_-_Pokemon.mid"]
NOTES = parse_corpus(corpi)

## Preprocess the data
NUM_NOTES = (len(NOTES) // BATCH_SIZE) * BATCH_SIZE
NOTES = NOTES[:NUM_NOTES]
NUM_FEATURES = len(NOTES[0])

feature_classes_count = [max(np.max(notes, axis=0)[i] + 1 for notes in [NOTES]) for i in range(NUM_FEATURES)]
features = [np.array([note[i] for note in NOTES]) for i in range(NUM_FEATURES)]
Xs = [
    np.zeros((NUM_NOTES - SEQUENCE_LENGTH, SEQUENCE_LENGTH, feature_classes_count[i]), dtype=np.int32)
    for i in range(NUM_FEATURES)]
ys = [np.zeros((NUM_NOTES - SEQUENCE_LENGTH, feature_classes_count[i]), dtype=np.int32) for i in range(NUM_FEATURES)]

for i in range(NUM_FEATURES):
    for j in range(NUM_NOTES - SEQUENCE_LENGTH):
        Xs[i][j] = to_categorical(features[i][j:j + SEQUENCE_LENGTH], num_classes=feature_classes_count[i])
        ys[i][j] = to_categorical(features[i][j + SEQUENCE_LENGTH], num_classes=feature_classes_count[i])
# Out:
# 2023-03-14 23:29:13.783 | INFO     | __main__:parse_corpus:4 - Parsing ./midi/pokemon/Pokemon_game_-_Pokemon.mid

# %%
# Define the model architecture
inputs = [Input(shape=(SEQUENCE_LENGTH, feature_classes_count[i])) for i in range(NUM_FEATURES)]
merged = concatenate(inputs)

lstm1 = LSTM(units=128, activation='tanh', return_sequences=True)(merged)
lstm2 = LSTM(units=128)(lstm1)
outputs = [Dense(feature_classes_count[i], activation='softmax', name=f'out{i}')(lstm2) for i in range(NUM_FEATURES)]

model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# Train the model
history = model.fit(Xs, ys, batch_size=BATCH_SIZE, epochs=EPOCHS, use_multiprocessing=True)
# Out:
# 2023-03-14 23:29:14.327812: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-14 23:29:14.327839: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (arceus): /proc/driver/nvidia/version does not exist
# 2023-03-14 23:29:14.328191: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 66/66 [==============================] - 4s 18ms/step - loss: 7.1209 - out0_loss: 0.7953 - out1_loss: 1.8152 - out2_loss: 2.4412 - out3_loss: 1.2651 - out4_loss: 0.4761 - out5_loss: 0.3279 - out0_categorical_accuracy: 0.7045 - out1_categorical_accuracy: 0.3504 - out2_categorical_accuracy: 0.2273 - out3_categorical_accuracy: 0.3958 - out4_categorical_accuracy: 0.9432 - out5_categorical_accuracy: 0.9451
# Epoch 2/100
# 66/66 [==============================] - 1s 18ms/step - loss: 6.3827 - out0_loss: 0.6865 - out1_loss: 1.7036 - out2_loss: 2.3418 - out3_loss: 1.1536 - out4_loss: 0.2776 - out5_loss: 0.2194 - out0_categorical_accuracy: 0.7330 - out1_categorical_accuracy: 0.3788 - out2_categorical_accuracy: 0.2254 - out3_categorical_accuracy: 0.4545 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 3/100
# 66/66 [==============================] - 1s 18ms/step - loss: 6.2610 - out0_loss: 0.6606 - out1_loss: 1.6799 - out2_loss: 2.3039 - out3_loss: 1.1260 - out4_loss: 0.2763 - out5_loss: 0.2143 - out0_categorical_accuracy: 0.7197 - out1_categorical_accuracy: 0.3939 - out2_categorical_accuracy: 0.2292 - out3_categorical_accuracy: 0.4356 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 4/100
# 66/66 [==============================] - 1s 18ms/step - loss: 5.9746 - out0_loss: 0.6132 - out1_loss: 1.5804 - out2_loss: 2.2511 - out3_loss: 1.0640 - out4_loss: 0.2663 - out5_loss: 0.1997 - out0_categorical_accuracy: 0.7405 - out1_categorical_accuracy: 0.4602 - out2_categorical_accuracy: 0.2500 - out3_categorical_accuracy: 0.5019 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 5/100
# 66/66 [==============================] - 1s 18ms/step - loss: 5.7856 - out0_loss: 0.6057 - out1_loss: 1.5060 - out2_loss: 2.1883 - out3_loss: 1.0369 - out4_loss: 0.2549 - out5_loss: 0.1938 - out0_categorical_accuracy: 0.7462 - out1_categorical_accuracy: 0.4905 - out2_categorical_accuracy: 0.2670 - out3_categorical_accuracy: 0.5076 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 6/100
# 66/66 [==============================] - 1s 18ms/step - loss: 5.5630 - out0_loss: 0.5868 - out1_loss: 1.4361 - out2_loss: 2.1326 - out3_loss: 0.9725 - out4_loss: 0.2462 - out5_loss: 0.1887 - out0_categorical_accuracy: 0.7500 - out1_categorical_accuracy: 0.5076 - out2_categorical_accuracy: 0.2708 - out3_categorical_accuracy: 0.5606 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 7/100
# 66/66 [==============================] - 1s 18ms/step - loss: 5.3595 - out0_loss: 0.5663 - out1_loss: 1.3608 - out2_loss: 2.0778 - out3_loss: 0.9266 - out4_loss: 0.2429 - out5_loss: 0.1850 - out0_categorical_accuracy: 0.7614 - out1_categorical_accuracy: 0.5322 - out2_categorical_accuracy: 0.3049 - out3_categorical_accuracy: 0.6023 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 8/100
# 66/66 [==============================] - 1s 18ms/step - loss: 5.1986 - out0_loss: 0.5467 - out1_loss: 1.3157 - out2_loss: 2.0222 - out3_loss: 0.8938 - out4_loss: 0.2412 - out5_loss: 0.1791 - out0_categorical_accuracy: 0.7689 - out1_categorical_accuracy: 0.5530 - out2_categorical_accuracy: 0.2936 - out3_categorical_accuracy: 0.5928 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 9/100
# 66/66 [==============================] - 1s 18ms/step - loss: 5.1122 - out0_loss: 0.5368 - out1_loss: 1.2832 - out2_loss: 1.9885 - out3_loss: 0.8929 - out4_loss: 0.2329 - out5_loss: 0.1779 - out0_categorical_accuracy: 0.7746 - out1_categorical_accuracy: 0.5436 - out2_categorical_accuracy: 0.3106 - out3_categorical_accuracy: 0.5890 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 10/100
# 66/66 [==============================] - 1s 18ms/step - loss: 4.9877 - out0_loss: 0.5155 - out1_loss: 1.2346 - out2_loss: 1.9764 - out3_loss: 0.8541 - out4_loss: 0.2323 - out5_loss: 0.1748 - out0_categorical_accuracy: 0.7841 - out1_categorical_accuracy: 0.5663 - out2_categorical_accuracy: 0.3409 - out3_categorical_accuracy: 0.6174 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 11/100
# 66/66 [==============================] - 1s 18ms/step - loss: 4.8632 - out0_loss: 0.5074 - out1_loss: 1.1998 - out2_loss: 1.9392 - out3_loss: 0.8163 - out4_loss: 0.2292 - out5_loss: 0.1713 - out0_categorical_accuracy: 0.8011 - out1_categorical_accuracy: 0.5928 - out2_categorical_accuracy: 0.3239 - out3_categorical_accuracy: 0.6515 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 12/100
# 66/66 [==============================] - 1s 18ms/step - loss: 4.6017 - out0_loss: 0.4463 - out1_loss: 1.1571 - out2_loss: 1.8641 - out3_loss: 0.7472 - out4_loss: 0.2226 - out5_loss: 0.1645 - out0_categorical_accuracy: 0.8239 - out1_categorical_accuracy: 0.6080 - out2_categorical_accuracy: 0.3371 - out3_categorical_accuracy: 0.6913 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 13/100
# 66/66 [==============================] - 1s 18ms/step - loss: 4.3678 - out0_loss: 0.3942 - out1_loss: 1.1101 - out2_loss: 1.7935 - out3_loss: 0.6999 - out4_loss: 0.2135 - out5_loss: 0.1566 - out0_categorical_accuracy: 0.8485 - out1_categorical_accuracy: 0.6117 - out2_categorical_accuracy: 0.3939 - out3_categorical_accuracy: 0.7083 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 14/100
# 66/66 [==============================] - 1s 18ms/step - loss: 4.1631 - out0_loss: 0.3481 - out1_loss: 1.0843 - out2_loss: 1.7217 - out3_loss: 0.6551 - out4_loss: 0.2055 - out5_loss: 0.1485 - out0_categorical_accuracy: 0.8845 - out1_categorical_accuracy: 0.6174 - out2_categorical_accuracy: 0.4261 - out3_categorical_accuracy: 0.7424 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 15/100
# 66/66 [==============================] - 1s 18ms/step - loss: 3.9486 - out0_loss: 0.3110 - out1_loss: 1.0483 - out2_loss: 1.6566 - out3_loss: 0.5884 - out4_loss: 0.2003 - out5_loss: 0.1440 - out0_categorical_accuracy: 0.8939 - out1_categorical_accuracy: 0.6345 - out2_categorical_accuracy: 0.4318 - out3_categorical_accuracy: 0.7879 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 16/100
# 66/66 [==============================] - 1s 18ms/step - loss: 3.7991 - out0_loss: 0.2712 - out1_loss: 1.0206 - out2_loss: 1.6183 - out3_loss: 0.5574 - out4_loss: 0.1940 - out5_loss: 0.1375 - out0_categorical_accuracy: 0.9072 - out1_categorical_accuracy: 0.6439 - out2_categorical_accuracy: 0.4318 - out3_categorical_accuracy: 0.7784 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 17/100
# 66/66 [==============================] - 1s 18ms/step - loss: 3.6358 - out0_loss: 0.2511 - out1_loss: 0.9867 - out2_loss: 1.5701 - out3_loss: 0.5155 - out4_loss: 0.1834 - out5_loss: 0.1289 - out0_categorical_accuracy: 0.9129 - out1_categorical_accuracy: 0.6705 - out2_categorical_accuracy: 0.4792 - out3_categorical_accuracy: 0.7936 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9583
# Epoch 18/100
# 66/66 [==============================] - 1s 18ms/step - loss: 3.4943 - out0_loss: 0.2235 - out1_loss: 0.9542 - out2_loss: 1.5189 - out3_loss: 0.4986 - out4_loss: 0.1788 - out5_loss: 0.1202 - out0_categorical_accuracy: 0.9299 - out1_categorical_accuracy: 0.6761 - out2_categorical_accuracy: 0.4830 - out3_categorical_accuracy: 0.8125 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9640
# Epoch 19/100
# 66/66 [==============================] - 1s 18ms/step - loss: 3.2985 - out0_loss: 0.1993 - out1_loss: 0.9055 - out2_loss: 1.4562 - out3_loss: 0.4537 - out4_loss: 0.1698 - out5_loss: 0.1141 - out0_categorical_accuracy: 0.9394 - out1_categorical_accuracy: 0.6970 - out2_categorical_accuracy: 0.5057 - out3_categorical_accuracy: 0.8333 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9678
# Epoch 20/100
# 66/66 [==============================] - 1s 18ms/step - loss: 3.1417 - out0_loss: 0.1749 - out1_loss: 0.8616 - out2_loss: 1.4107 - out3_loss: 0.4353 - out4_loss: 0.1553 - out5_loss: 0.1039 - out0_categorical_accuracy: 0.9508 - out1_categorical_accuracy: 0.7216 - out2_categorical_accuracy: 0.5379 - out3_categorical_accuracy: 0.8390 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9640
# Epoch 21/100
# 66/66 [==============================] - 1s 18ms/step - loss: 3.0923 - out0_loss: 0.1655 - out1_loss: 0.8600 - out2_loss: 1.3801 - out3_loss: 0.4293 - out4_loss: 0.1533 - out5_loss: 0.1041 - out0_categorical_accuracy: 0.9508 - out1_categorical_accuracy: 0.7083 - out2_categorical_accuracy: 0.5417 - out3_categorical_accuracy: 0.8258 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9678
# Epoch 22/100
# 66/66 [==============================] - 1s 18ms/step - loss: 2.8982 - out0_loss: 0.1438 - out1_loss: 0.8048 - out2_loss: 1.3340 - out3_loss: 0.3798 - out4_loss: 0.1405 - out5_loss: 0.0952 - out0_categorical_accuracy: 0.9508 - out1_categorical_accuracy: 0.7311 - out2_categorical_accuracy: 0.5720 - out3_categorical_accuracy: 0.8636 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9678
# Epoch 23/100
# 66/66 [==============================] - 1s 18ms/step - loss: 2.7624 - out0_loss: 0.1314 - out1_loss: 0.7742 - out2_loss: 1.2927 - out3_loss: 0.3544 - out4_loss: 0.1297 - out5_loss: 0.0801 - out0_categorical_accuracy: 0.9640 - out1_categorical_accuracy: 0.7519 - out2_categorical_accuracy: 0.5739 - out3_categorical_accuracy: 0.8769 - out4_categorical_accuracy: 0.9583 - out5_categorical_accuracy: 0.9754
# Epoch 24/100
# 66/66 [==============================] - 1s 18ms/step - loss: 2.6227 - out0_loss: 0.1185 - out1_loss: 0.7224 - out2_loss: 1.2378 - out3_loss: 0.3336 - out4_loss: 0.1296 - out5_loss: 0.0808 - out0_categorical_accuracy: 0.9640 - out1_categorical_accuracy: 0.7576 - out2_categorical_accuracy: 0.5852 - out3_categorical_accuracy: 0.8807 - out4_categorical_accuracy: 0.9621 - out5_categorical_accuracy: 0.9754
# Epoch 25/100
# 66/66 [==============================] - 1s 18ms/step - loss: 2.5275 - out0_loss: 0.1064 - out1_loss: 0.7058 - out2_loss: 1.2070 - out3_loss: 0.3268 - out4_loss: 0.1113 - out5_loss: 0.0702 - out0_categorical_accuracy: 0.9697 - out1_categorical_accuracy: 0.7557 - out2_categorical_accuracy: 0.5909 - out3_categorical_accuracy: 0.8636 - out4_categorical_accuracy: 0.9659 - out5_categorical_accuracy: 0.9773
# Epoch 26/100
# 66/66 [==============================] - 1s 18ms/step - loss: 2.3759 - out0_loss: 0.0965 - out1_loss: 0.6536 - out2_loss: 1.1571 - out3_loss: 0.2911 - out4_loss: 0.1084 - out5_loss: 0.0692 - out0_categorical_accuracy: 0.9697 - out1_categorical_accuracy: 0.7917 - out2_categorical_accuracy: 0.6212 - out3_categorical_accuracy: 0.8958 - out4_categorical_accuracy: 0.9659 - out5_categorical_accuracy: 0.9754
# Epoch 27/100
# 66/66 [==============================] - 1s 18ms/step - loss: 2.2856 - out0_loss: 0.0935 - out1_loss: 0.6418 - out2_loss: 1.1165 - out3_loss: 0.2765 - out4_loss: 0.0966 - out5_loss: 0.0606 - out0_categorical_accuracy: 0.9678 - out1_categorical_accuracy: 0.7879 - out2_categorical_accuracy: 0.6269 - out3_categorical_accuracy: 0.8977 - out4_categorical_accuracy: 0.9678 - out5_categorical_accuracy: 0.9754
# Epoch 28/100
# 66/66 [==============================] - 1s 18ms/step - loss: 2.1690 - out0_loss: 0.0800 - out1_loss: 0.6070 - out2_loss: 1.0673 - out3_loss: 0.2569 - out4_loss: 0.0952 - out5_loss: 0.0626 - out0_categorical_accuracy: 0.9754 - out1_categorical_accuracy: 0.8106 - out2_categorical_accuracy: 0.6553 - out3_categorical_accuracy: 0.9053 - out4_categorical_accuracy: 0.9678 - out5_categorical_accuracy: 0.9735
# Epoch 29/100
# 66/66 [==============================] - 1s 18ms/step - loss: 2.0786 - out0_loss: 0.0674 - out1_loss: 0.5740 - out2_loss: 1.0375 - out3_loss: 0.2544 - out4_loss: 0.0866 - out5_loss: 0.0587 - out0_categorical_accuracy: 0.9886 - out1_categorical_accuracy: 0.8144 - out2_categorical_accuracy: 0.6723 - out3_categorical_accuracy: 0.9091 - out4_categorical_accuracy: 0.9735 - out5_categorical_accuracy: 0.9811
# Epoch 30/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.9279 - out0_loss: 0.0564 - out1_loss: 0.5406 - out2_loss: 0.9888 - out3_loss: 0.2175 - out4_loss: 0.0775 - out5_loss: 0.0471 - out0_categorical_accuracy: 0.9830 - out1_categorical_accuracy: 0.8239 - out2_categorical_accuracy: 0.6875 - out3_categorical_accuracy: 0.9337 - out4_categorical_accuracy: 0.9716 - out5_categorical_accuracy: 0.9811
# Epoch 31/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.9188 - out0_loss: 0.0716 - out1_loss: 0.5248 - out2_loss: 0.9644 - out3_loss: 0.2170 - out4_loss: 0.0846 - out5_loss: 0.0563 - out0_categorical_accuracy: 0.9830 - out1_categorical_accuracy: 0.8295 - out2_categorical_accuracy: 0.6875 - out3_categorical_accuracy: 0.9205 - out4_categorical_accuracy: 0.9716 - out5_categorical_accuracy: 0.9792
# Epoch 32/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.8066 - out0_loss: 0.0609 - out1_loss: 0.5026 - out2_loss: 0.9243 - out3_loss: 0.2003 - out4_loss: 0.0729 - out5_loss: 0.0457 - out0_categorical_accuracy: 0.9830 - out1_categorical_accuracy: 0.8277 - out2_categorical_accuracy: 0.7178 - out3_categorical_accuracy: 0.9413 - out4_categorical_accuracy: 0.9735 - out5_categorical_accuracy: 0.9811
# Epoch 33/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.6300 - out0_loss: 0.0444 - out1_loss: 0.4502 - out2_loss: 0.8601 - out3_loss: 0.1768 - out4_loss: 0.0633 - out5_loss: 0.0353 - out0_categorical_accuracy: 0.9905 - out1_categorical_accuracy: 0.8636 - out2_categorical_accuracy: 0.7500 - out3_categorical_accuracy: 0.9451 - out4_categorical_accuracy: 0.9792 - out5_categorical_accuracy: 0.9886
# Epoch 34/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.5548 - out0_loss: 0.0370 - out1_loss: 0.4383 - out2_loss: 0.8269 - out3_loss: 0.1650 - out4_loss: 0.0554 - out5_loss: 0.0322 - out0_categorical_accuracy: 0.9962 - out1_categorical_accuracy: 0.8769 - out2_categorical_accuracy: 0.7367 - out3_categorical_accuracy: 0.9318 - out4_categorical_accuracy: 0.9830 - out5_categorical_accuracy: 0.9905
# Epoch 35/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.5019 - out0_loss: 0.0377 - out1_loss: 0.4233 - out2_loss: 0.7861 - out3_loss: 0.1633 - out4_loss: 0.0586 - out5_loss: 0.0329 - out0_categorical_accuracy: 0.9905 - out1_categorical_accuracy: 0.8598 - out2_categorical_accuracy: 0.7557 - out3_categorical_accuracy: 0.9413 - out4_categorical_accuracy: 0.9811 - out5_categorical_accuracy: 0.9867
# Epoch 36/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.6022 - out0_loss: 0.0632 - out1_loss: 0.4307 - out2_loss: 0.8204 - out3_loss: 0.1941 - out4_loss: 0.0590 - out5_loss: 0.0348 - out0_categorical_accuracy: 0.9830 - out1_categorical_accuracy: 0.8636 - out2_categorical_accuracy: 0.7595 - out3_categorical_accuracy: 0.9261 - out4_categorical_accuracy: 0.9830 - out5_categorical_accuracy: 0.9848
# Epoch 37/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.3740 - out0_loss: 0.0336 - out1_loss: 0.3839 - out2_loss: 0.7383 - out3_loss: 0.1426 - out4_loss: 0.0473 - out5_loss: 0.0283 - out0_categorical_accuracy: 0.9943 - out1_categorical_accuracy: 0.8902 - out2_categorical_accuracy: 0.7803 - out3_categorical_accuracy: 0.9508 - out4_categorical_accuracy: 0.9943 - out5_categorical_accuracy: 0.9905
# Epoch 38/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.2446 - out0_loss: 0.0306 - out1_loss: 0.3405 - out2_loss: 0.6783 - out3_loss: 0.1191 - out4_loss: 0.0464 - out5_loss: 0.0298 - out0_categorical_accuracy: 0.9943 - out1_categorical_accuracy: 0.8996 - out2_categorical_accuracy: 0.7860 - out3_categorical_accuracy: 0.9735 - out4_categorical_accuracy: 0.9867 - out5_categorical_accuracy: 0.9924
# Epoch 39/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.3338 - out0_loss: 0.0438 - out1_loss: 0.3645 - out2_loss: 0.7112 - out3_loss: 0.1384 - out4_loss: 0.0480 - out5_loss: 0.0279 - out0_categorical_accuracy: 0.9830 - out1_categorical_accuracy: 0.8958 - out2_categorical_accuracy: 0.7992 - out3_categorical_accuracy: 0.9564 - out4_categorical_accuracy: 0.9867 - out5_categorical_accuracy: 0.9924
# Epoch 40/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.1425 - out0_loss: 0.0259 - out1_loss: 0.3153 - out2_loss: 0.6304 - out3_loss: 0.1023 - out4_loss: 0.0423 - out5_loss: 0.0262 - out0_categorical_accuracy: 0.9943 - out1_categorical_accuracy: 0.9148 - out2_categorical_accuracy: 0.8295 - out3_categorical_accuracy: 0.9754 - out4_categorical_accuracy: 0.9905 - out5_categorical_accuracy: 0.9943
# Epoch 41/100
# 66/66 [==============================] - 1s 18ms/step - loss: 1.0251 - out0_loss: 0.0243 - out1_loss: 0.2830 - out2_loss: 0.5652 - out3_loss: 0.0929 - out4_loss: 0.0361 - out5_loss: 0.0236 - out0_categorical_accuracy: 0.9962 - out1_categorical_accuracy: 0.9356 - out2_categorical_accuracy: 0.8409 - out3_categorical_accuracy: 0.9811 - out4_categorical_accuracy: 0.9924 - out5_categorical_accuracy: 0.9943
# Epoch 42/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.9900 - out0_loss: 0.0303 - out1_loss: 0.2709 - out2_loss: 0.5474 - out3_loss: 0.0904 - out4_loss: 0.0310 - out5_loss: 0.0199 - out0_categorical_accuracy: 0.9981 - out1_categorical_accuracy: 0.9280 - out2_categorical_accuracy: 0.8598 - out3_categorical_accuracy: 0.9792 - out4_categorical_accuracy: 0.9962 - out5_categorical_accuracy: 0.9924
# Epoch 43/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.9160 - out0_loss: 0.0205 - out1_loss: 0.2545 - out2_loss: 0.5111 - out3_loss: 0.0775 - out4_loss: 0.0309 - out5_loss: 0.0216 - out0_categorical_accuracy: 0.9962 - out1_categorical_accuracy: 0.9375 - out2_categorical_accuracy: 0.8750 - out3_categorical_accuracy: 0.9905 - out4_categorical_accuracy: 0.9962 - out5_categorical_accuracy: 0.9943
# Epoch 44/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.8254 - out0_loss: 0.0181 - out1_loss: 0.2243 - out2_loss: 0.4738 - out3_loss: 0.0611 - out4_loss: 0.0295 - out5_loss: 0.0186 - out0_categorical_accuracy: 0.9981 - out1_categorical_accuracy: 0.9489 - out2_categorical_accuracy: 0.8864 - out3_categorical_accuracy: 0.9962 - out4_categorical_accuracy: 0.9981 - out5_categorical_accuracy: 0.9981
# Epoch 45/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.8239 - out0_loss: 0.0188 - out1_loss: 0.2400 - out2_loss: 0.4528 - out3_loss: 0.0641 - out4_loss: 0.0283 - out5_loss: 0.0199 - out0_categorical_accuracy: 0.9962 - out1_categorical_accuracy: 0.9337 - out2_categorical_accuracy: 0.8864 - out3_categorical_accuracy: 0.9886 - out4_categorical_accuracy: 0.9962 - out5_categorical_accuracy: 0.9962
# Epoch 46/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.7399 - out0_loss: 0.0168 - out1_loss: 0.2036 - out2_loss: 0.4205 - out3_loss: 0.0568 - out4_loss: 0.0246 - out5_loss: 0.0176 - out0_categorical_accuracy: 0.9981 - out1_categorical_accuracy: 0.9583 - out2_categorical_accuracy: 0.9015 - out3_categorical_accuracy: 0.9924 - out4_categorical_accuracy: 0.9981 - out5_categorical_accuracy: 0.9981
# Epoch 47/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.6702 - out0_loss: 0.0138 - out1_loss: 0.1876 - out2_loss: 0.3795 - out3_loss: 0.0501 - out4_loss: 0.0234 - out5_loss: 0.0158 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9545 - out2_categorical_accuracy: 0.9129 - out3_categorical_accuracy: 0.9943 - out4_categorical_accuracy: 0.9981 - out5_categorical_accuracy: 0.9943
# Epoch 48/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.6903 - out0_loss: 0.0225 - out1_loss: 0.1918 - out2_loss: 0.3668 - out3_loss: 0.0618 - out4_loss: 0.0267 - out5_loss: 0.0206 - out0_categorical_accuracy: 0.9924 - out1_categorical_accuracy: 0.9602 - out2_categorical_accuracy: 0.9261 - out3_categorical_accuracy: 0.9867 - out4_categorical_accuracy: 0.9962 - out5_categorical_accuracy: 0.9962
# Epoch 49/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.6735 - out0_loss: 0.0197 - out1_loss: 0.1956 - out2_loss: 0.3640 - out3_loss: 0.0528 - out4_loss: 0.0245 - out5_loss: 0.0169 - out0_categorical_accuracy: 0.9943 - out1_categorical_accuracy: 0.9545 - out2_categorical_accuracy: 0.9223 - out3_categorical_accuracy: 0.9924 - out4_categorical_accuracy: 0.9962 - out5_categorical_accuracy: 0.9981
# Epoch 50/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.5861 - out0_loss: 0.0130 - out1_loss: 0.1677 - out2_loss: 0.3204 - out3_loss: 0.0483 - out4_loss: 0.0212 - out5_loss: 0.0155 - out0_categorical_accuracy: 0.9962 - out1_categorical_accuracy: 0.9735 - out2_categorical_accuracy: 0.9375 - out3_categorical_accuracy: 0.9886 - out4_categorical_accuracy: 0.9943 - out5_categorical_accuracy: 0.9962
# Epoch 51/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.5423 - out0_loss: 0.0128 - out1_loss: 0.1548 - out2_loss: 0.2990 - out3_loss: 0.0423 - out4_loss: 0.0198 - out5_loss: 0.0135 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9735 - out2_categorical_accuracy: 0.9564 - out3_categorical_accuracy: 0.9962 - out4_categorical_accuracy: 0.9962 - out5_categorical_accuracy: 0.9981
# Epoch 52/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.4581 - out0_loss: 0.0094 - out1_loss: 0.1339 - out2_loss: 0.2579 - out3_loss: 0.0310 - out4_loss: 0.0156 - out5_loss: 0.0103 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9848 - out2_categorical_accuracy: 0.9564 - out3_categorical_accuracy: 0.9981 - out4_categorical_accuracy: 0.9981 - out5_categorical_accuracy: 0.9981
# Epoch 53/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.4363 - out0_loss: 0.0108 - out1_loss: 0.1250 - out2_loss: 0.2434 - out3_loss: 0.0297 - out4_loss: 0.0154 - out5_loss: 0.0120 - out0_categorical_accuracy: 0.9981 - out1_categorical_accuracy: 0.9848 - out2_categorical_accuracy: 0.9735 - out3_categorical_accuracy: 0.9981 - out4_categorical_accuracy: 0.9981 - out5_categorical_accuracy: 0.9981
# Epoch 54/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.4039 - out0_loss: 0.0107 - out1_loss: 0.1121 - out2_loss: 0.2265 - out3_loss: 0.0287 - out4_loss: 0.0142 - out5_loss: 0.0116 - out0_categorical_accuracy: 0.9981 - out1_categorical_accuracy: 0.9867 - out2_categorical_accuracy: 0.9678 - out3_categorical_accuracy: 0.9962 - out4_categorical_accuracy: 0.9962 - out5_categorical_accuracy: 0.9962
# Epoch 55/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.3807 - out0_loss: 0.0090 - out1_loss: 0.1130 - out2_loss: 0.2118 - out3_loss: 0.0266 - out4_loss: 0.0117 - out5_loss: 0.0087 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9811 - out2_categorical_accuracy: 0.9735 - out3_categorical_accuracy: 0.9981 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 56/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.3519 - out0_loss: 0.0081 - out1_loss: 0.1088 - out2_loss: 0.1932 - out3_loss: 0.0228 - out4_loss: 0.0107 - out5_loss: 0.0084 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9886 - out2_categorical_accuracy: 0.9792 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 0.9981
# Epoch 57/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.3629 - out0_loss: 0.0097 - out1_loss: 0.1126 - out2_loss: 0.1896 - out3_loss: 0.0295 - out4_loss: 0.0119 - out5_loss: 0.0096 - out0_categorical_accuracy: 0.9981 - out1_categorical_accuracy: 0.9754 - out2_categorical_accuracy: 0.9754 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 0.9981 - out5_categorical_accuracy: 0.9981
# Epoch 58/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.4185 - out0_loss: 0.0082 - out1_loss: 0.1410 - out2_loss: 0.2128 - out3_loss: 0.0381 - out4_loss: 0.0102 - out5_loss: 0.0081 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9716 - out2_categorical_accuracy: 0.9640 - out3_categorical_accuracy: 0.9962 - out4_categorical_accuracy: 0.9981 - out5_categorical_accuracy: 0.9981
# Epoch 59/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.3202 - out0_loss: 0.0065 - out1_loss: 0.1027 - out2_loss: 0.1680 - out3_loss: 0.0272 - out4_loss: 0.0091 - out5_loss: 0.0067 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9811 - out2_categorical_accuracy: 0.9792 - out3_categorical_accuracy: 0.9962 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 60/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.2721 - out0_loss: 0.0059 - out1_loss: 0.0844 - out2_loss: 0.1466 - out3_loss: 0.0190 - out4_loss: 0.0091 - out5_loss: 0.0071 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9886 - out2_categorical_accuracy: 0.9848 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 61/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.2443 - out0_loss: 0.0049 - out1_loss: 0.0806 - out2_loss: 0.1300 - out3_loss: 0.0158 - out4_loss: 0.0074 - out5_loss: 0.0057 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9867 - out2_categorical_accuracy: 0.9848 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 62/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.2149 - out0_loss: 0.0049 - out1_loss: 0.0658 - out2_loss: 0.1177 - out3_loss: 0.0150 - out4_loss: 0.0067 - out5_loss: 0.0049 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9943 - out2_categorical_accuracy: 0.9924 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 63/100
# 66/66 [==============================] - 1s 19ms/step - loss: 0.1981 - out0_loss: 0.0046 - out1_loss: 0.0623 - out2_loss: 0.1060 - out3_loss: 0.0144 - out4_loss: 0.0060 - out5_loss: 0.0048 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9962 - out2_categorical_accuracy: 0.9962 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 64/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1853 - out0_loss: 0.0039 - out1_loss: 0.0601 - out2_loss: 0.0988 - out3_loss: 0.0126 - out4_loss: 0.0056 - out5_loss: 0.0044 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9924 - out2_categorical_accuracy: 0.9943 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 65/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1754 - out0_loss: 0.0038 - out1_loss: 0.0574 - out2_loss: 0.0926 - out3_loss: 0.0123 - out4_loss: 0.0053 - out5_loss: 0.0040 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9924 - out2_categorical_accuracy: 0.9924 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 66/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.2209 - out0_loss: 0.0057 - out1_loss: 0.0836 - out2_loss: 0.1067 - out3_loss: 0.0144 - out4_loss: 0.0059 - out5_loss: 0.0047 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9830 - out2_categorical_accuracy: 0.9924 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 67/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.2410 - out0_loss: 0.0049 - out1_loss: 0.0712 - out2_loss: 0.1238 - out3_loss: 0.0270 - out4_loss: 0.0080 - out5_loss: 0.0062 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9867 - out2_categorical_accuracy: 0.9792 - out3_categorical_accuracy: 0.9962 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 68/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1723 - out0_loss: 0.0038 - out1_loss: 0.0543 - out2_loss: 0.0913 - out3_loss: 0.0143 - out4_loss: 0.0050 - out5_loss: 0.0035 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9981 - out2_categorical_accuracy: 0.9943 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 69/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1423 - out0_loss: 0.0034 - out1_loss: 0.0458 - out2_loss: 0.0752 - out3_loss: 0.0099 - out4_loss: 0.0042 - out5_loss: 0.0037 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9981 - out2_categorical_accuracy: 0.9943 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 70/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1286 - out0_loss: 0.0032 - out1_loss: 0.0402 - out2_loss: 0.0687 - out3_loss: 0.0088 - out4_loss: 0.0041 - out5_loss: 0.0035 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9981 - out2_categorical_accuracy: 0.9924 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 71/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1427 - out0_loss: 0.0028 - out1_loss: 0.0494 - out2_loss: 0.0726 - out3_loss: 0.0109 - out4_loss: 0.0038 - out5_loss: 0.0032 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9924 - out2_categorical_accuracy: 0.9924 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 72/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1287 - out0_loss: 0.0031 - out1_loss: 0.0485 - out2_loss: 0.0614 - out3_loss: 0.0091 - out4_loss: 0.0035 - out5_loss: 0.0031 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9981 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 73/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1496 - out0_loss: 0.0043 - out1_loss: 0.0628 - out2_loss: 0.0647 - out3_loss: 0.0099 - out4_loss: 0.0044 - out5_loss: 0.0035 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9924 - out2_categorical_accuracy: 0.9981 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 74/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1095 - out0_loss: 0.0027 - out1_loss: 0.0420 - out2_loss: 0.0513 - out3_loss: 0.0076 - out4_loss: 0.0032 - out5_loss: 0.0028 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9962 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 75/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0957 - out0_loss: 0.0025 - out1_loss: 0.0344 - out2_loss: 0.0457 - out3_loss: 0.0078 - out4_loss: 0.0028 - out5_loss: 0.0024 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9962 - out2_categorical_accuracy: 0.9981 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 76/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0873 - out0_loss: 0.0022 - out1_loss: 0.0332 - out2_loss: 0.0407 - out3_loss: 0.0061 - out4_loss: 0.0027 - out5_loss: 0.0023 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9962 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 77/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0849 - out0_loss: 0.0022 - out1_loss: 0.0348 - out2_loss: 0.0368 - out3_loss: 0.0062 - out4_loss: 0.0026 - out5_loss: 0.0022 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9943 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 78/100
# 66/66 [==============================] - 1s 19ms/step - loss: 0.0753 - out0_loss: 0.0021 - out1_loss: 0.0289 - out2_loss: 0.0340 - out3_loss: 0.0057 - out4_loss: 0.0024 - out5_loss: 0.0021 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9962 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 79/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0666 - out0_loss: 0.0019 - out1_loss: 0.0241 - out2_loss: 0.0311 - out3_loss: 0.0052 - out4_loss: 0.0023 - out5_loss: 0.0019 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9981 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 80/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0617 - out0_loss: 0.0018 - out1_loss: 0.0217 - out2_loss: 0.0292 - out3_loss: 0.0051 - out4_loss: 0.0022 - out5_loss: 0.0018 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9981 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 81/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0609 - out0_loss: 0.0017 - out1_loss: 0.0233 - out2_loss: 0.0273 - out3_loss: 0.0048 - out4_loss: 0.0021 - out5_loss: 0.0017 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9981 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 82/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0566 - out0_loss: 0.0016 - out1_loss: 0.0205 - out2_loss: 0.0263 - out3_loss: 0.0046 - out4_loss: 0.0020 - out5_loss: 0.0016 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9981 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 83/100
# 66/66 [==============================] - 1s 19ms/step - loss: 0.0530 - out0_loss: 0.0016 - out1_loss: 0.0192 - out2_loss: 0.0244 - out3_loss: 0.0043 - out4_loss: 0.0019 - out5_loss: 0.0016 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9981 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 84/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0530 - out0_loss: 0.0015 - out1_loss: 0.0207 - out2_loss: 0.0234 - out3_loss: 0.0042 - out4_loss: 0.0018 - out5_loss: 0.0015 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9962 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 85/100
# 66/66 [==============================] - 1s 19ms/step - loss: 0.0516 - out0_loss: 0.0014 - out1_loss: 0.0213 - out2_loss: 0.0216 - out3_loss: 0.0041 - out4_loss: 0.0017 - out5_loss: 0.0014 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9981 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 86/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0490 - out0_loss: 0.0015 - out1_loss: 0.0194 - out2_loss: 0.0211 - out3_loss: 0.0040 - out4_loss: 0.0016 - out5_loss: 0.0014 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 0.9962 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 87/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0426 - out0_loss: 0.0013 - out1_loss: 0.0156 - out2_loss: 0.0194 - out3_loss: 0.0035 - out4_loss: 0.0016 - out5_loss: 0.0013 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 88/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0391 - out0_loss: 0.0013 - out1_loss: 0.0136 - out2_loss: 0.0181 - out3_loss: 0.0035 - out4_loss: 0.0015 - out5_loss: 0.0013 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 89/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0371 - out0_loss: 0.0013 - out1_loss: 0.0126 - out2_loss: 0.0173 - out3_loss: 0.0033 - out4_loss: 0.0014 - out5_loss: 0.0012 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 90/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0350 - out0_loss: 0.0012 - out1_loss: 0.0120 - out2_loss: 0.0163 - out3_loss: 0.0031 - out4_loss: 0.0014 - out5_loss: 0.0011 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 91/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0335 - out0_loss: 0.0011 - out1_loss: 0.0114 - out2_loss: 0.0156 - out3_loss: 0.0030 - out4_loss: 0.0013 - out5_loss: 0.0011 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 92/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0315 - out0_loss: 0.0011 - out1_loss: 0.0107 - out2_loss: 0.0146 - out3_loss: 0.0029 - out4_loss: 0.0012 - out5_loss: 0.0010 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 93/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0302 - out0_loss: 0.0011 - out1_loss: 0.0105 - out2_loss: 0.0137 - out3_loss: 0.0028 - out4_loss: 0.0012 - out5_loss: 9.9043e-04 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 94/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0284 - out0_loss: 9.6021e-04 - out1_loss: 0.0093 - out2_loss: 0.0134 - out3_loss: 0.0027 - out4_loss: 0.0011 - out5_loss: 9.3000e-04 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 95/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0271 - out0_loss: 9.4465e-04 - out1_loss: 0.0089 - out2_loss: 0.0128 - out3_loss: 0.0025 - out4_loss: 0.0011 - out5_loss: 9.0219e-04 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 96/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0254 - out0_loss: 8.6933e-04 - out1_loss: 0.0082 - out2_loss: 0.0120 - out3_loss: 0.0024 - out4_loss: 0.0010 - out5_loss: 8.6021e-04 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 97/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0240 - out0_loss: 8.6499e-04 - out1_loss: 0.0077 - out2_loss: 0.0114 - out3_loss: 0.0023 - out4_loss: 9.9956e-04 - out5_loss: 8.0491e-04 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 98/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0228 - out0_loss: 8.0390e-04 - out1_loss: 0.0074 - out2_loss: 0.0108 - out3_loss: 0.0021 - out4_loss: 9.3585e-04 - out5_loss: 7.6790e-04 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 99/100
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0218 - out0_loss: 7.8237e-04 - out1_loss: 0.0070 - out2_loss: 0.0103 - out3_loss: 0.0021 - out4_loss: 9.2350e-04 - out5_loss: 7.5652e-04 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000
# Epoch 100/100
# 66/66 [==============================] - 1s 19ms/step - loss: 0.0209 - out0_loss: 7.5523e-04 - out1_loss: 0.0067 - out2_loss: 0.0098 - out3_loss: 0.0020 - out4_loss: 8.8332e-04 - out5_loss: 7.0963e-04 - out0_categorical_accuracy: 1.0000 - out1_categorical_accuracy: 1.0000 - out2_categorical_accuracy: 1.0000 - out3_categorical_accuracy: 1.0000 - out4_categorical_accuracy: 1.0000 - out5_categorical_accuracy: 1.0000

# %%
def predict_sequence(model, seed_sequence, num_features):
    # Encode the seed sequence
    slen = len(seed_sequence[0])
    seed_sequence = [seed_sequence[i][-slen:] for i in range(num_features)]
    seed_sequence = [
        to_categorical([seed_sequence[i]], num_classes=feature_classes_count[i]) for i in range(num_features)]
    # Predict the next feature values in the sequence
    predicted_features = model.predict(seed_sequence, verbose=0)
    # Decode the predicted feature values
    next_features = [np.argmax(predicted_features[i][0]) for i in range(num_features)]
    return next_features


def generate_song(model, seed_sequence, generated_length, num_features):
    slen = len(seed_sequence[0])
    current_sequence = [list(reversed(seed_sequence[i][:slen])) for i in range(num_features)]
    # song = [seed_sequence[i][:slen] for i in range(num_features)]
    generated = np.asarray([[] for i in range(num_features)], dtype=int)
    for i in range(generated_length - slen):
        next_features = predict_sequence(model, current_sequence, num_features)
        print(f"Predicted feature: {next_features}")
        current_sequence = np.hstack((current_sequence, np.transpose([next_features])))
        current_sequence = np.delete(current_sequence, 0, axis=1)
        generated = np.hstack((generated, np.transpose([next_features])), dtype=int)
    return generated


# Set the seed sequence and the desired length of the generated song
seed_sequence = [features[i][:SEQUENCE_LENGTH] for i in range(NUM_FEATURES)]
GENERATED_LENGTH = 50

# Generate the song
song = generate_song(model, seed_sequence, GENERATED_LENGTH, NUM_FEATURES)
song = np.transpose(song)
play_song(song)
# Out:
# Predicted feature: [2, 1, 3, 4, 0, 0]
# Predicted feature: [2, 1, 3, 4, 0, 0]
# Predicted feature: [2, 2, 8, 4, 0, 0]
# Predicted feature: [2, 2, 10, 4, 0, 0]
# Predicted feature: [2, 2, 12, 4, 0, 0]
# Predicted feature: [2, 2, 1, 5, 0, 0]
# Predicted feature: [2, 1, 12, 4, 0, 0]
# Predicted feature: [2, 1, 3, 4, 0, 0]
# Predicted feature: [2, 1, 8, 4, 0, 0]
