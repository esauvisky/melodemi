# %%
#!/usr/bin/env python3
import os
import sys

import music21
import numpy as np
from keras.layers import LSTM, Dense, Input, concatenate
from keras.models import Model
from keras.utils import to_categorical
from loguru import logger
from midi2audio import FluidSynth
from tqdm import tqdm

SEQUENCE_LENGTH = 16
BATCH_SIZE = 16
EPOCHS = 100

# %%
def setup_logging(level="DEBUG", show_module=False):
    """
    Setups better log format for loguru
    """
    logger.remove(0)    # Remove the default logger
    log_level = level
    log_fmt = u"<green>["
    log_fmt += u"{file:10.10}…:{line:<3} | " if show_module else ""
    log_fmt += u"{time:HH:mm:ss.SSS}]</green> <level>{level: <8}</level> | <level>{message}</level>"
    logger.add(sys.stderr, level=log_level, format=log_fmt, colorize=True, backtrace=True, diagnose=True)


def play_midi(midi_file):
    #Play MIDI
    sf2_path = '/usr/share/soundfonts/freepats-general-midi.sf2' # path to sound font file
    FluidSynth(sound_font=sf2_path).play_midi(midi_file)

# %%
# Load the musical data using Music21
# corpi = [os.path.join('./midi', f) for f in os.listdir('./midi') if f.endswith('.mid')]
corpi = [c for c in music21.corpus.getComposer("mozart")[1:3]]

notes = []
ql_to_ordinal = {}
ordinal_to_ql = {}
for corpus in corpi:
    logger.info(f'Parsing {corpus}')
    parsed = music21.converter.parse(corpus)
    elements = parsed.flat.notes
    for element in elements:
        if isinstance(element, music21.note.Note):
            ql_to_ordinal[element.duration.quarterLength] = element.duration.ordinal
            ordinal_to_ql[element.duration.ordinal] = element.duration.quarterLength
            notes.append((element.pitch.pitchClass, element.pitch.octave, element.duration.ordinal))

# Preprocess the data
sequence_length = SEQUENCE_LENGTH
n_samples = (len(notes) // BATCH_SIZE) * BATCH_SIZE
notes = notes[:n_samples]
num_features = len(notes[0])

feature_classes_count = [max(np.max(notes, axis=0)[i] + 1 for notes in [notes]) for i in range(num_features)]
features = [np.array([note[i] for note in notes]) for i in range(num_features)]
Xs = [
    np.zeros((len(notes) - sequence_length, sequence_length, feature_classes_count[i]), dtype=np.int32)
    for i in range(num_features)]
ys = [np.zeros((len(notes) - sequence_length, feature_classes_count[i]), dtype=np.int32) for i in range(num_features)]

for i in range(num_features):
    for j in range(len(notes) - sequence_length):
        Xs[i][j] = to_categorical(features[i][j:j + sequence_length], num_classes=feature_classes_count[i])
        ys[i][j] = to_categorical(features[i][j + sequence_length], num_classes=feature_classes_count[i])
# Out:
# 2023-02-26 07:16:40.890 | INFO     | __main__:<module>:9 - Parsing /home/emi/Coding/melodemi/.venv/lib/python3.10/site-packages/music21/corpus/mozart/k155/movement2.mxl
# 2023-02-26 07:16:41.266 | INFO     | __main__:<module>:9 - Parsing /home/emi/Coding/melodemi/.venv/lib/python3.10/site-packages/music21/corpus/mozart/k155/movement3.mxl

# %%
# Define the model architecture
inputs = [Input(shape=(sequence_length, feature_classes_count[i])) for i in range(num_features)]
merged = concatenate(inputs)

lstm1 = LSTM(units=64, activation='tanh', return_sequences=True)(merged)
lstm2 = LSTM(units=64)(lstm1)
outputs = [Dense(feature_classes_count[i], activation='softmax', name=f'out{i}')(lstm2) for i in range(num_features)]

model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# Train the model
history = model.fit(Xs, ys, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=1)
# Out:
# Epoch 1/100
# 126/126 [==============================] - 4s 6ms/step - loss: 4.7299 - out0_loss: 2.2405 - out1_loss: 1.3255 - out2_loss: 1.1639 - out0_categorical_accuracy: 0.1592 - out1_categorical_accuracy: 0.3790 - out2_categorical_accuracy: 0.5957
# Epoch 2/100
# 126/126 [==============================] - 1s 6ms/step - loss: 4.3463 - out0_loss: 2.1707 - out1_loss: 1.2238 - out2_loss: 0.9518 - out0_categorical_accuracy: 0.1736 - out1_categorical_accuracy: 0.4003 - out2_categorical_accuracy: 0.6374
# Epoch 3/100
# 126/126 [==============================] - 1s 5ms/step - loss: 4.2742 - out0_loss: 2.1286 - out1_loss: 1.2182 - out2_loss: 0.9274 - out0_categorical_accuracy: 0.1944 - out1_categorical_accuracy: 0.4117 - out2_categorical_accuracy: 0.6409
# Epoch 4/100
# 126/126 [==============================] - 1s 5ms/step - loss: 4.1809 - out0_loss: 2.0909 - out1_loss: 1.1970 - out2_loss: 0.8930 - out0_categorical_accuracy: 0.2123 - out1_categorical_accuracy: 0.4395 - out2_categorical_accuracy: 0.6607
# Epoch 5/100
# 126/126 [==============================] - 1s 5ms/step - loss: 4.1096 - out0_loss: 2.0529 - out1_loss: 1.1866 - out2_loss: 0.8701 - out0_categorical_accuracy: 0.2262 - out1_categorical_accuracy: 0.4405 - out2_categorical_accuracy: 0.6577
# Epoch 6/100
# 126/126 [==============================] - 1s 5ms/step - loss: 4.0433 - out0_loss: 2.0242 - out1_loss: 1.1693 - out2_loss: 0.8498 - out0_categorical_accuracy: 0.2128 - out1_categorical_accuracy: 0.4544 - out2_categorical_accuracy: 0.6672
# Epoch 7/100
# 126/126 [==============================] - 1s 5ms/step - loss: 4.0034 - out0_loss: 2.0037 - out1_loss: 1.1607 - out2_loss: 0.8390 - out0_categorical_accuracy: 0.2163 - out1_categorical_accuracy: 0.4608 - out2_categorical_accuracy: 0.6721
# Epoch 8/100
# 126/126 [==============================] - 1s 5ms/step - loss: 3.9559 - out0_loss: 1.9819 - out1_loss: 1.1505 - out2_loss: 0.8235 - out0_categorical_accuracy: 0.2331 - out1_categorical_accuracy: 0.4559 - out2_categorical_accuracy: 0.6786
# Epoch 9/100
# 126/126 [==============================] - 1s 5ms/step - loss: 3.9117 - out0_loss: 1.9643 - out1_loss: 1.1405 - out2_loss: 0.8069 - out0_categorical_accuracy: 0.2431 - out1_categorical_accuracy: 0.4658 - out2_categorical_accuracy: 0.6716
# Epoch 10/100
# 126/126 [==============================] - 1s 5ms/step - loss: 3.8640 - out0_loss: 1.9485 - out1_loss: 1.1207 - out2_loss: 0.7948 - out0_categorical_accuracy: 0.2470 - out1_categorical_accuracy: 0.4673 - out2_categorical_accuracy: 0.6865
# Epoch 11/100
# 126/126 [==============================] - 1s 5ms/step - loss: 3.8254 - out0_loss: 1.9316 - out1_loss: 1.1161 - out2_loss: 0.7777 - out0_categorical_accuracy: 0.2579 - out1_categorical_accuracy: 0.4891 - out2_categorical_accuracy: 0.6860
# Epoch 12/100
# 126/126 [==============================] - 1s 5ms/step - loss: 3.7845 - out0_loss: 1.9166 - out1_loss: 1.1112 - out2_loss: 0.7567 - out0_categorical_accuracy: 0.2584 - out1_categorical_accuracy: 0.4787 - out2_categorical_accuracy: 0.6930
# Epoch 13/100
# 126/126 [==============================] - 1s 5ms/step - loss: 3
100
# 126/126 [==============================] - 1s 5ms/step - loss: 0.1025 - out0_loss: 0.0594 - out1_loss: 0.0256 - out2_loss: 0.0174 - out0_categorical_accuracy: 0.9945 - out1_categorical_accuracy: 0.9955 - out2_categorical_accuracy: 0.9985
# Epoch 94/100
# 126/126 [==============================] - 1s 5ms/step - loss: 0.0908 - out0_loss: 0.0530 - out1_loss: 0.0229 - out2_loss: 0.0149 - out0_categorical_accuracy: 0.9945 - out1_categorical_accuracy: 0.9960 - out2_categorical_accuracy: 0.9990
# Epoch 95/100
# 126/126 [==============================] - 1s 5ms/step - loss: 0.0840 - out0_loss: 0.0495 - out1_loss: 0.0201 - out2_loss: 0.0144 - out0_categorical_accuracy: 0.9955 - out1_categorical_accuracy: 0.9970 - out2_categorical_accuracy: 0.9995
# Epoch 96/100
# 126/126 [==============================] - 1s 5ms/step - loss: 0.0788 - out0_loss: 0.0460 - out1_loss: 0.0196 - out2_loss: 0.0131 - out0_categorical_accuracy: 0.9945 - out1_categorical_accuracy: 0.9960 - out2_categorical_accuracy: 0.9995
# Epoch 97/100
# 126/126 [==============================] - 1s 6ms/step - loss: 0.0747 - out0_loss: 0.0437 - out1_loss: 0.0189 - out2_loss: 0.0121 - out0_categorical_accuracy: 0.9945 - out1_categorical_accuracy: 0.9970 - out2_categorical_accuracy: 0.9995
# Epoch 98/100
# 126/126 [==============================] - 1s 5ms/step - loss: 0.0714 - out0_loss: 0.0408 - out1_loss: 0.0188 - out2_loss: 0.0118 - out0_categorical_accuracy: 0.9955 - out1_categorical_accuracy: 0.9965 - out2_categorical_accuracy: 0.9990
# Epoch 99/100
# 126/126 [==============================] - 1s 5ms/step - loss: 0.0684 - out0_loss: 0.0392 - out1_loss: 0.0175 - out2_loss: 0.0118 - out0_categorical_accuracy: 0.9945 - out1_categorical_accuracy: 0.9960 - out2_categorical_accuracy: 0.9990
# Epoch 100/100
# 126/126 [==============================] - 1s 5ms/step - loss: 0.0646 - out0_loss: 0.0376 - out1_loss: 0.0164 - out2_loss: 0.0105 - out0_categorical_accuracy: 0.9926 - out1_categorical_accuracy: 0.9970 - out2_categorical_accuracy: 0.9990

# %%
def predict_sequence(model, seed_sequence, sequence_length, num_features):
    # Encode the seed sequence
    seed_sequence = [seed_sequence[i][-sequence_length:] for i in range(num_features)]
    seed_sequence = [to_categorical([seed_sequence[i]], num_classes=feature_classes_count[i]) for i in range(num_features)]
    # Predict the next feature values in the sequence
    predicted_features = model.predict(seed_sequence, verbose=0)
    # Decode the predicted feature values
    next_features = [np.argmax(predicted_features[i][0]) for i in range(num_features)]

    return next_features


def generate_song(model, seed_sequence, sequence_length, song_length, num_features):
    song = [list(reversed(seed_sequence[i][:sequence_length])) for i in range(num_features)]
    for i in range(song_length - sequence_length):
        next_features = predict_sequence(model, song, sequence_length, num_features)
        print(f"Predicted feature: {next_features}")
        song = [np.append(song[i], next_features[i]) for i in range(num_features)]
    return song


# Set the seed sequence and the desired length of the generated song
seed_sequence = features
song_length = 256

# Generate the song
song = generate_song(model, seed_sequence, sequence_length, song_length, num_features)
# Out:
# Predicted feature: [4, 4, 7]
# Predicted feature: [9, 3, 7]
# Predicted feature: [9, 4, 6]
# Predicted feature: [1, 2, 7]
# Predicted feature: [9, 4, 6]
# Predicted feature: [2, 4, 8]
# Predicted feature: [4, 4, 8]
# Predicted feature: [1, 5, 8]
# Predicted feature: [9, 2, 7]
# Predicted feature: [2, 4, 7]
# Predicted feature: [2, 4, 8]
# Predicted feature: [11, 2, 8]
# Predicted feature: [1, 5, 8]
# Predicted feature: [11, 4, 8]
# Predicted feature: [11, 4, 8]
# Predicted feature: [2, 5, 8]
# Predicted feature: [9, 2, 7]
# Predicted feature: [4, 2, 6]
# Predicted feature: [8, 4, 8]
# Predicted feature: [3, 4, 8]
# Predicted feature: [11, 4, 7]
# Predicted feature: [11, 3, 8]
# Predicted feature: [3, 2, 7]
# Predicted feature: [6, 2, 7]
# Predicted feature: [4, 4, 8]
# Predicted feature: [11, 4, 8]
# Predicted feature: [6, 4, 7]
# Predicted feature: [1, 4, 7]
# Predicted feature: [8, 4, 7]
# Predicted feature: [8, 4, 7]
# Predicted feature: [3, 4, 6]
# Predicted feature: [11, 4, 7]
# Predicted feature: [11, 4, 6]
# Predicted feature: [11, 4, 6]
# Predicted feature: [8, 4, 6]
# Predicted feature: [8, 4, 8]
# Predicted feature: [9, 4, 6]
# Predicted feature: [3, 4, 6]
# Predicted feature: [11, 2, 8]
# Predicted feature: [9, 2, 7]
# Predicted feature: [8, 4, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [1, 4, 8]
# Predicted feature: [2, 4, 6]
# Predicted feature: [2, 4, 6]
# Predicted feature: [4, 3, 6]
# Predicted feature: [4, 5, 8]
# Predicted feature: [0, 5, 8]
# Predicted feature: [1, 4, 8]
# Predicted feature: [4, 4, 6]
# Predicted feature: [4, 3, 6]
# Predicted feature: [4, 4, 8]
# Predicted feature: [8, 5, 8]
# Predicted feature: [11, 4, 7]
# Predicted feature: [11, 3, 6]
# Predicted feature: [4, 2, 6]
# Predicted feature: [8, 4, 8]
# Predicted feature: [11, 4, 8]
# Predicted feature: [6, 4, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [3, 4, 8]
# Predicted feature: [6, 4, 8]
# Predicted feature: [8, 4, 8]
# Predicted feature: [8, 4, 8]
# Predicted feature: [11, 3, 8]
# Predicted feature: [3, 4, 8]
# Predicted feature: [3, 4, 8]
# Predicted feature: [8, 4, 8]
# Predicted feature: [6, 4, 5]
# Predicted feature: [4, 4, 8]
# Predicted feature: [4, 4, 8]
# Predicted feature: [8, 4, 7]
# Predicted feature: [8, 4, 5]
# Predicted feature: [4, 4, 5]
# Predicted feature: [4, 4, 6]
# Predicted feature: [9, 2, 6]
# Predicted feature: [1, 4, 7]
# Predicted feature: [1, 4, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [1, 4, 7]
# Predicted feature: [9, 4, 7]
# Predicted feature: [8, 4, 7]
# Predicted feature: [11, 2, 6]
# Predicted feature: [1, 2, 5]
# Predicted feature: [4, 5, 7]
# Predicted feature: [2, 5, 8]
# Predicted feature: [11, 5, 8]
# Predicted feature: [1, 4, 8]
# Predicted feature: [9, 3, 7]
# Predicted feature: [1, 5, 8]
# Predicted feature: [9, 5, 8]
# Predicted feature: [3, 5, 8]
# Predicted feature: [9, 5, 8]
# Predicted feature: [4, 2, 7]
# Predicted feature: [3, 5, 8]
# Predicted feature: [3, 4, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [3, 5, 8]
# Predicted feature: [6, 4, 8]
# Predicted feature: [9, 4, 5]
# Predicted feature: [4, 3, 7]
# Predicted feature: [8, 4, 8]
# Predicted feature: [8, 4, 8]
# Predicted feature: [4, 2, 7]
# Predicted feature: [4, 4, 8]
# Predicted feature: [8, 4, 8]
# Predicted feature: [6, 4, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [3, 4, 7]
# Predicted feature: [8, 4, 5]
# Predicted feature: [5, 4, 8]
# Predicted feature: [9, 4, 5]
# Predicted feature: [4, 4, 6]
# Predicted feature: [9, 2, 6]
# Predicted feature: [11, 3, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [1, 4, 8]
# Predicted feature: [1, 4, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [2, 4, 8]
# Predicted feature: [4, 4, 8]
# Predicted feature: [1, 4, 6]
# Predicted feature: [9, 4, 8]
# Predicted feature: [4, 4, 8]
# Predicted feature: [4, 2, 6]
# Predicted feature: [4, 4, 6]
# Predicted feature: [9, 4, 8]
# Predicted feature: [11, 4, 6]
# Predicted feature: [8, 2, 6]
# Predicted feature: [8, 4, 6]
# Predicted feature: [11, 2, 6]
# Predicted feature: [11, 4, 7]
# Predicted feature: [1, 5, 8]
# Predicted feature: [11, 4, 7]
# Predicted feature: [11, 4, 7]
# Predicted feature: [8, 4, 6]
# Predicted feature: [4, 2, 6]
# Predicted feature: [4, 5, 8]
# Predicted feature: [8, 4, 8]
# Predicted feature: [3, 4, 8]
# Predicted feature: [3, 4, 8]
# Predicted feature: [3, 4, 8]
# Predicted feature: [1, 5, 8]
# Predicted feature: [0, 4, 8]
# Predicted feature: [4, 6, 8]
# Predicted feature: [3, 5, 8]
# Predicted feature: [4, 4, 8]
# Predicted feature: [6, 5, 8]
# Predicted feature: [4, 4, 5]
# Predicted feature: [4, 5, 6]
# Predicted feature: [4, 4, 6]
# Predicted feature: [8, 2, 8]
# Predicted feature: [8, 4, 8]
# Predicted feature: [8, 4, 8]
# Predicted feature: [8, 2, 8]
# Predicted feature: [8, 4, 8]
# Predicted feature: [8, 4, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [9, 5, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [1, 5, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [2, 3, 6]
# Predicted feature: [10, 4, 6]
# Predicted feature: [11, 4, 8]
# Predicted feature: [6, 4, 8]
# Predicted feature: [1, 5, 8]
# Predicted feature: [1, 4, 8]
# Predicted feature: [1, 6, 8]
# Predicted feature: [1, 6, 8]
# Predicted feature: [2, 6, 8]
# Predicted feature: [2, 6, 8]
# Predicted feature: [2, 6, 8]
# Predicted feature: [2, 6, 6]
# Predicted feature: [4, 6, 8]
# Predicted feature: [4, 5, 8]
# Predicted feature: [4, 5, 8]
# Predicted feature: [4, 5, 7]
# Predicted feature: [1, 4, 6]
# Predicted feature: [11, 3, 6]
# Predicted feature: [4, 4, 7]
# Predicted feature: [4, 4, 6]
# Predicted feature: [4, 3, 6]
# Predicted feature: [1, 4, 6]
# Predicted feature: [9, 2, 6]
# Predicted feature: [9, 5, 8]
# Predicted feature: [1, 5, 8]
# Predicted feature: [9, 5, 8]
# Predicted feature: [11, 5, 8]
# Predicted feature: [9, 4, 8]
# Predicted feature: [1, 4, 8]
# Predicted feature: [2, 6, 8]
# Predicted feature: [2, 4, 8]
# Predicted feature: [3, 5, 8]
# Predicted feature: [4, 4, 8]
# Predicted feature: [3, 5, 8]
# Predicted feature: [2, 4, 8]
# Predicted feature: [1, 4, 8]
# Predicted feature: [4, 2, 8]
# Predicted feature: [3, 4, 8]
# Predicted feature: [11, 4, 8]
# Predicted feature: [4, 4, 7]
# Predicted feature: [1, 2, 7]
# Predicted feature: [4, 4, 7]
# Predicted feature: [11, 4, 6]
# Predicted feature: [11, 4, 6]
# Predicted feature: [5, 4, 5]
# Predicted feature: [11, 4, 7]
# Predicted feature: [8, 4, 7]
# Predicted feature: [8, 4, 7]
# Predicted feature: [8, 4, 5]
# Predicted feature: [3, 4, 6]
# Predicted feature: [4, 4, 6]
# Predicted feature: [4, 4, 7]
# Predicted feature: [3, 2, 5]
# Predicted feature: [9, 2, 5]
# Predicted feature: [9, 4, 7]
# Predicted feature: [6, 4, 7]
# Predicted feature: [6, 4, 7]
# Predicted feature: [4, 5, 7]
# Predicted feature: [4, 4, 7]
# Predicted feature: [4, 3, 6]
# Predicted feature: [4, 4, 6]
# Predicted feature: [6, 4, 6]
# Predicted feature: [8, 4, 6]
# Predicted feature: [9, 4, 8]
# Predicted feature: [8, 4, 7]
# Predicted feature: [4, 5, 8]
# Predicted feature: [2, 3, 7]
# Predicted feature: [9, 3, 6]
# Predicted feature: [6, 3, 6]
# Predicted feature: [11, 4, 8]
# Predicted feature: [8, 3, 7]
# Predicted feature: [9, 4, 8]
# Predicted feature: [8, 4, 8]
# Predicted feature: [11, 3, 8]
# Predicted feature: [8, 5, 8]
# Predicted feature: [8, 5, 7]
# Predicted feature: [9, 4, 8]

# %%
# Write the generated stream to a MIDI file
stream = music21.stream.Stream()

for (pitch, octave, duration) in zip(song[0], song[1], song[2]):
    _pitch = music21.pitch.Pitch(pitch, octave=octave)
    note = music21.note.Note(pitch=_pitch, duration=music21.duration.Duration(ordinal_to_ql[duration]))
    stream.append(note)

stream.write('midi', fp='generated_music.mid')
play_midi('generated_music.mid')
# Out:
# ALSA lib pcm_dsnoop.c:566:(snd_pcm_dsnoop_open) unable to open slave
# ALSA lib pcm_dmix.c:999:(snd_pcm_dmix_open) unable to open slave
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.rear
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.center_lfe
# ALSA lib pcm.c:2666:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.side
# Cannot connect to server socket err = No such file or directory
# Cannot connect to server request channel
# jack server is not running or cannot be started
# JackShmReadWritePtr::~JackShmReadWritePtr - Init not done for -1, skipping unlock
# JackShmReadWritePtr::~JackShmReadWritePtr - Init not done for -1, skipping unlock
# Cannot connect to server socket err = No such file or directory
# Cannot connect to server request channel
# jack server is not running or cannot be started
# JackShmReadWritePtr::~JackShmReadWritePtr - Init not done for -1, skipping unlock
# JackShmReadWritePtr::~JackShmReadWritePtr - Init not done for -1, skipping unlock
# ALSA lib pcm_oss.c:397:(_snd_pcm_oss_open) Cannot open device /dev/dsp
# ALSA lib pcm_oss.c:397:(_snd_pcm_oss_open) Cannot open device /dev/dsp
# ALSA lib pcm_a52.c:1001:(_snd_pcm_a52_open) a52 is only for playback
# ALSA lib confmisc.c:160:(snd_config_get_card) Invalid field card
# ALSA lib pcm_usb_stream.c:482:(_snd_pcm_usb_stream_open) Invalid card 'card'
# ALSA lib confmisc.c:160:(snd_config_get_card) Invalid field card
# ALSA lib pcm_usb_stream.c:482:(_snd_pcm_usb_stream_open) Invalid card 'card'
# ALSA lib pcm_dmix.c:999:(snd_pcm_dmix_open) unable to open slave
# Cannot connect to server socket err = No such file or directory
# Cannot connect to server request channel
# jack server is not running or cannot be started
# JackShmReadWritePtr::~JackShmReadWritePtr - Init not done for -1, skipping unlock
# JackShmReadWritePtr::~JackShmReadWritePtr - Init not done for -1, skipping unlock
# fluidsynth: warning: Failed to set thread to high priority
# fluidsynth: warning: Failed to set thread to high priority
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 10
#       7     stream.append(note)
#       9 stream.write('midi', fp='generated_music.mid')
# ---> 10 play_midi('generated_music.mid')
#
# Cell In[12], line 16, in play_midi(midi_file)
#      13 def play_midi(midi_file):
#      14     #Play MIDI
#      15     sf2_path = '/usr/share/soundfonts/freepats-general-midi.sf2' # path to sound font file
# ---> 16     FluidSynth(sound_font=sf2_path).play_midi(midi_file)
#
# File ~/Coding/melodemi/.venv/lib/python3.10/site-packages/midi2audio.py:49, in FluidSynth.play_midi(self, midi_file)
#      48 def play_midi(self, midi_file):
# ---> 49     subprocess.call(['fluidsynth', '-i', self.sound_font, midi_file, '-r', str(self.sample_rate)])
#
# File /usr/lib/python3.10/subprocess.py:347, in call(timeout, *popenargs, **kwargs)
#     345 with Popen(*popenargs, **kwargs) as p:
#     346     try:
# --> 347         return p.wait(timeout=timeout)
#     348     except:  # Including KeyboardInterrupt, wait handled that.
#     349         p.kill()
#
# File /usr/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:1943, in Popen._wait(self, timeout)
#    1941 if self.returncode is not None:
#    1942     break  # Another thread waited.
# -> 1943 (pid, sts) = self._try_wait(0)
#    1944 # Check the pid and loop as waitpid has been known to
#    1945 # return 0 even without WNOHANG in odd situations.
#    1946 # http://bugs.python.org/issue14396.
#    1947 if pid == self.pid:
#
# File /usr/lib/python3.10/subprocess.py:1901, in Popen._try_wait(self, wait_flags)
#    1899 """All callers to this function MUST hold self._waitpid_lock."""
#    1900 try:
# -> 1901     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1902 except ChildProcessError:
#    1903     # This happens if SIGCLD is set to be ignored or waiting
#    1904     # for child processes has otherwise been disabled for our
#    1905     # process.  This child is dead, we can't get the status.
#    1906     pid = self.pid
#
# KeyboardInterrupt:
